# %%
#task 1 
movie = ["Jawan", "Pathaan", "KGF", "Leo", "Pushpa"]
movie_iter = iter(movie)

print(next(movie_iter))
print(next(movie_iter))
print(next(movie_iter))
print(next(movie_iter))
print(next(movie_iter))
# Out:
# Jawan
# Pathaan
# KGF
# Leo
# Pushpa

# %%
#task 2 
songs = ["Kesariya", "Blinding Lights", "Perfect", "Levitating", "Shape of You", "Believer"]

for index, song in enumerate(songs, start=1):
    print(f"{index}. {song}")
# Out:
# 1. Kesariya
# 2. Blinding Lights
# 3. Perfect
# 4. Levitating
# 5. Shape of You
# 6. Believer

# %%
#task 3
foods = ["Pizza", "Burger", "Pasta", "Sandwich"]
prices = [250, 150, 200, 120]

for food, price in zip(foods, prices):
    print(f"{food} - ₹{price}")
# Out:
# Pizza - ₹250
# Burger - ₹150
# Pasta - ₹200
# Sandwich - ₹120

# %%
#task 4
def insta_posts_generator(posts):
    for post in posts:
        yield post

posts = ["Sunset vibes 🌅", "Gym time 💪", "Food love 🍕"]

gen = insta_posts_generator(posts)

try:
    while True:
        print(next(gen))
except StopIteration:
    print("No more posts!")
# Out:
# Sunset vibes 🌅
# Gym time 💪
# Food love 🍕
# No more posts!

# %%
#task 5
def cashback_generator(transactions):
    for amount in transactions:
        yield amount * 0.05   # 5% cashback

transactions = [100, 500, 1000, 200]

for cashback in cashback_generator(transactions):
    print("Cashback:", cashback)
# Out:
# Cashback: 5.0
# Cashback: 25.0
# Cashback: 50.0
# Cashback: 10.0
