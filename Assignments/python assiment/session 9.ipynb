# %%
# task 1
def calculate_final_price(price, discount_rate):
    return price - (price * discount_rate)
print(calculate_final_price(1200,0.15))
# Out:
# 1020.0

# %%
#task 2 
def get_dilivary_charge(amount,city= 'Ahemdabad'):
    if city == "Ahmedabad":
        return 30
    else:
        return 50
print(get_dilivary_charge(500))
print(get_dilivary_charge(500,"surat"))
# Out:
# 50
# 50

# %%
#task 3
def format_coupon_message(username, discount=10):
    return f"Hi {username}, you get {discount}% off!"

print(format_coupon_message("Rahul", 20))
print(format_coupon_message("Amit"))
# Out:
# Hi Rahul, you get 20% off!
# Hi Amit, you get 10% off!

# %%
#task4
def apply_discount(price, rate=0.10):
    return price - (price * rate)

print(apply_discount(1000))   # default 10%
# Out:
# 900.0

# %%
#task 5
def calculate_cashback(amount,cashback_rate=0.05):
    return amount * cashback_rate
print("Zometo Cashback",calculate_cashback(500))
print("Flipcart cashbbok:",calculate_cashback(2000,0.07))
# Out:
# Zometo Cashback 25.0
# Flipcart cashbbok: 140.0
