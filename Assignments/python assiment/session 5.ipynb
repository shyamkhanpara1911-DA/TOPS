# %%
#task 1 

playlist_ids = [101,102,103,104,105]
playlist_ids.append(106)
print(playlist_ids)
# Out:
# [101, 102, 103, 104, 105, 106]

# %%
#task 2 
cart_items  = ['t-shirt','shoes']
cart_items.extend(['jeans', 'cap'])
print(cart_items)
# Out:
# ['t-shirt', 'shoes', 'jeans', 'cap']

# %%
#task 3 

def remove_last_item(order_list):
    return order_list.pop()
order = ['pizza','barger','coke']
remove = remove_last_item(order)
print("remove item:",remove)
print("update order:",order)
# Out:
# remove item: coke
# update order: ['pizza', 'barger']

# %%
#task 4 
insta_filters = ("Clarendon", " Jumo", "Lark", "gingham")
insta_filters[1] = "NewFilter"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 #task 4
#       2 insta_filters = ("Clarendon", " Jumo", "Lark", "gingham")
# ----> 3 insta_filters[1] = "NewFilter"
#
# TypeError: 'tuple' object does not support item assignment

# %%
#task 5
# Favorite genres → List (change થઈ શકે)
genres = ["Pop", "Rock", "Hip-Hop"]

# Train classes → Tuple (fixed values)
train_classes = ("Sleeper", "AC 3 Tier", "AC 2 Tier")
