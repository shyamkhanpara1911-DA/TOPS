# %%
#task 1
playlist_prices = {"Top Hits":100,"workout Mix":150,"chill vibs":120,"party song":200, "romantic":130 }
print(playlist_prices)
# Out:
# {'Top Hits': 100, 'workout Mix': 150, 'chill vibs': 120, 'party song': 200, 'romantic': 130}

# %%
#task 2
def update_playlist_price(playlist,new_price):
    playlist_prices[playlist] =new_price
update_playlist_price("top hits",180)
print(playlist_prices)
# Out:
# {'Top Hits': 100, 'workout Mix': 150, 'chill vibs': 120, 'party song': 200, 'romantic': 130, 'top hits': 180}

# %%
#task 
del playlist_prices["romantic"]
print(playlist_prices)
# Out:
# {'Top Hits': 100, 'workout Mix': 150, 'chill vibs': 120, 'party song': 200, 'top hits': 180}

# %%
#task 4

zometo = {"Dominos", "Kfc","McDonals","Pizza hut"}
swiggy = {"KFC", "Burger King", "Pizza Hut", "Subway"}
print("union",zometo.union(swiggy))
print("Intersection:", zomato.intersection(swiggy))
# Out:
# union {'Kfc', 'Pizza Hut', 'McDonals', 'Dominos', 'KFC', 'Burger King', 'Subway', 'Pizza hut'}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 6
#       2
#       3 zometo = {"Dominos", "Kfc","McDonals","Pizza hut"}
#       4 swiggy = {"KFC", "Burger King", "Pizza Hut", "Subway"}
#       5 print("union",zometo.union(swiggy))
# ----> 6 print("Intersection:", zomato.intersection(swiggy))
#
# NameError: name 'zomato' is not defined
