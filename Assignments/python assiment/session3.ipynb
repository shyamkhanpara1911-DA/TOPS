# %%
#task 1 
followers = 1000
rating = 4.5
app_name = "instagram"
is_premium_user = True

print(followers,type(followers))
print(rating,type(rating))
print(app_name,type(app_name))
print(is_premium_user,type(is_premium_user))
# Out:
# 1000 <class 'int'>
# 4.5 <class 'float'>
# instagram <class 'str'>
# True <class 'bool'>

# %%
#task 2
price = input ("enter zometo order price")
price = float(price)
final_bill = price + (price * 0.18)
print("final_bill amount:",final_bill)
# Out:
# final_bill amount: 118.0

# %%
price = input("enter a price")
price = float(price)
finalamount = price + (price * 0.25)
print("final bill:",finalamount)
# Out:
# final bill: 154016.25

# %%
#task 3 
prices = ['199.99', '299.50', '150']

total = 0

for p in prices:
    total += float(p)

print("Total cart value:", total)
# Out:
# Total cart value: 649.49

# %%
# task 4 
def is_discount_applicable(order_amount):
    return order_amount>500
print(is_discount_applicable(450))
print(is_discount_applicable(750))
# Out:
# False
# True

# %%
#task 5 
ratings = ['4.5', '3.0', '5', '4.2']

ratings_float = [float(r) for r in ratings]

print("Highest rating:", max(ratings_float))
# Out:
# Highest rating: 5.0
