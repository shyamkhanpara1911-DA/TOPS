# %%
#task 1
def safe_divide(a,b):
    try:
        return a/b
    except ZeroDivisionError:
        return "cannot divide by zero"
    print(safe_divide(10,2))
    print(safe_divide(10,0))

# %%
#task 2 Zometo rating System
try:
    reviews = int(input("enter number of reviews:"))
    stars = int(input("enter total stars:"))
    avg = stars / reviews
    print("avarage Rating",avg)
except ValueError:
    print("invalid input! plase enter number only.")
except ZeroDivisionError:
    print("Reviews cannot be zero.")
# Out:
# avarage Rating 1.0

# %%
#task 3
class InvalidDurationError(Exception):
    pass

def get_playlist_duration(songs):
    total = 0
    
    for duration in songs:
        if duration < 0:
            raise InvalidDurationError("Duration cannot be negative")
        total += duration
    
    return total / 60   # minutes

try:
    print(get_playlist_duration([120, 200, -50]))
except InvalidDurationError as e:
    print("Error:", e)
# Out:
# Error: Duration cannot be negative

# %%
#task 4
try:
    price = float(input("enter item price:"))
    qty = int(input("enter quantity"))
except ValueError:
    print("invalide input! enter valide number.")
else:
    total = price * qty
    print("total price",total)
finally:
    print("thank you for shoping !")
# Out:
# total price 1000.0
# thank you for shoping !

# %%
#task 5
try:
    a = float(input("enter first number:"))
    b = float(input("enter secound nuber:"))
    result = a/b
    print("result",result)
except ValueError:
    print("invalide input! plase enter number.")
except ZeroDivisionError:
    print("cannot divid by zero.")
# Out:
# result 1.0
