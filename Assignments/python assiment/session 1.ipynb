# %% [markdown]
# # task 2

# %%
print("my name is shyam ")
print("my favorite app is instagram")
# Out:
# my name is shyam
# my favorite app is instagram

# %% [markdown]
# # task 3

# %%
print("welcome to data analits to python!")
# Out:
# welcome to data analits to python!

# %%
# task 4

# %%
import datetime 
year = datetime.datetime.now().year
print(year)
# Out:
# 2026
