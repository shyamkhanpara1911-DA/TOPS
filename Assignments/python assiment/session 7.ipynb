# %%
#task 1
age = int(input("enter a age "))
if age >=18:
    
    print("Eligible for IPL ticket booking")
else:
    print("not eligible")
# Out:
# Eligible for IPL ticket booking

# %%
age = int(input("enter a age:"))
if age >=18 and   age<50:
    print("eligible for vote")
else:
    print("not eligible")
# Out:
# eligible for vote

# %%
#task 2
followers = int(input("enter number of followers"))
if followers<1000:
    print("Micro Influencer")
if followers<=10000:
    print("Rising star")
else:
    print("celebrity")
# Out:
# Micro Influencer
# Rising star

# %%
#task 3
total = float(input("enter order total:"))
if total >299:
    print("Applay Free Dilivary")
elif 200 <= total <=299:
    print("Add more items for free dilivary ")
else:
    print("Delivery charges apply")
# Out:
# Delivery charges apply

# %%
#task 4
cart_value = float(input("Enter cart value: "))
payment = input("Enter payment method (UPI/Card/Cash): ")

if cart_value > 1000:
    if payment == "UPI":
        print("Eligible for 10% cashback")
    else:
        print("Eligible for 5% cashback")
else:
    print("No cashback")
# Out:
# No cashback
