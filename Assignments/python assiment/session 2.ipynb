# %%
#task 1 
user_name = "Shyam"
fav_app = "Instagram"
daily_usage_hours = 3

print(user_name)
print(fav_app)
print(daily_usage_hours)
# Out:
# Shyam
# Instagram
# 3

# %%
# task 2
product_name = "samrtphone"
price = 15000
is_available = True 

print(product_name,type(product_name))
print(price,type(price))
print(is_available,type(is_available))
# Out:
# samrtphone <class 'str'>
# 15000 <class 'int'>
# True <class 'bool'>

# %%
#task 3 
# This is a single-line comment
# Spotify recommends songs based on user listening history

"""
This is a multi-line comment
Spotify system works like:
- Track your songs
- Analyze your taste
- Suggest similar songs
"""

print("Spotify recommendation system example")

# %%
#task 4
order_total = 500
dilivary_region = "ahemdabad"
discount_percent = 20 
print(f"order from {dilivary_region} totals {order_total} with {discount_percent}% discount.")
# Out:
# order from ahemdabad totals 500 with 20% discount.

# %%
#task 5 
if True:
   print("hello")
   print("word")
# Out:
# hello
# word
