# %%
#task 1
import math
num = 16 
print("Square root:",math.sqrt(num))
print("factorial",math.factorial(5))
print("value of pi:",math.pi)
# Out:
# Square root: 4.0
# factorial 120
# value of pi: 3.141592653589793

# %%
#task 2
import os

files = os.listdir()

for file in files:
    if file.endswith(".jpg") or file.endswith(".png"):
        print(file)

# %%
#task 3
from datetime import datetime

date_input = input("Enter date (YYYY-MM-DD): ")

date_obj = datetime.strptime(date_input, "%Y-%m-%d")

print("Day:", date_obj.strftime("%A"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 6
#       2 from datetime import datetime
#       3
#       4 date_input = input("Enter date (YYYY-MM-DD): ")
#       5
# ----> 6 date_obj = datetime.strptime(date_input, "%Y-%m-%d")
#       7
#       8 print("Day:", date_obj.strftime("%A"))
#
# File c:\Users\shyam\AppData\Local\Python\pythoncore-3.14-64\Lib\_strptime.py:815, in _strptime_datetime_datetime(cls, data_string, format)
#     812 def _strptime_datetime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     813     """Return a datetime instance based on the input string and the
#     814     format string."""
# --> 815     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     816     tzname, gmtoff = tt[-2:]
#     817     args = tt[:6] + (fraction,)
#
# File c:\Users\shyam\AppData\Local\Python\pythoncore-3.14-64\Lib\_strptime.py:555, in _strptime(data_string, format)
#     553 found = format_regex.match(data_string)
#     554 if not found:
# --> 555     raise ValueError("time data %r does not match format %r" %
#     556                      (data_string, format))
#     557 if len(data_string) != found.end():
#     558     raise ValueError("unconverted data remains: %s" %
#     559                       data_string[found.end():])
#
# ValueError: time data '2006/08/01' does not match format '%Y-%m-%d'

# %%
#task 4
def format_follower_count(n):
    if n >= 1000000:
        return f"{n/1000000:.1f}M"
    elif n >= 1000:
        return f"{n/1000:.1f}K"
    else:
        return str(n)

# %%
import statistics
Number = [10,20,30,40,50]
print("Avarage:",statistics.mean(Number))
# Out:
# Avarage: 30
