# %%
#task 1
order_amount = [120,250,90,310,150]
total = 0
for amount in order_amount:
    total+= amount
print("Total order value:",total)
# Out:
# Total order value: 920

# %%
#task 2
scores = [45, 78, 102, 34, 67, 89]
i = 0
while i <len(scores):
    if scores[i] > 100:
        break
    print(scores[i])
    i += 1
# Out:
# 45
# 78

# %%
#task 3
prices = [299, 499, 199, 999, 149]
total = 0
for price in prices:
    if price < 200:
        continue
    total += price
print("Total after skipping:", total)
# Out:
# Total after skipping: 1797

# %%
#task 4 
songs = ['Kesariya', 'Believer', 'Shape of You', 'Blinding Lights', 'Excuses']
for i, song in enumerate(songs,start=1):
    print(f"{i}.{song}")
# Out:
# 1.Kesariya
# 2.Believer
# 3.Shape of You
# 4.Blinding Lights
# 5.Excuses

# %%
#task 5
followers = [120, 1500, 23000, 800, 45000]
for f in followers:
    if f < 1000:
        print("Micro")
    elif f <=10000:
        print("Influencer")
    else:
        print("Celebrity")
# Out:
# Micro
# Influencer
# Celebrity
# Micro
# Celebrity
