# %%
#task 1
gst = lambda price: price + (price * 0.18)

print(gst(100))
print(gst(250))
print(gst(500))
# Out:
# 118.0
# 295.0
# 590.0

# %%
#task 2
songs = [' shape OF you ', ' believer ', ' BLINDING lights ']

cleaned = list(map(lambda s: s.strip().title(), songs))

#print(cleaned)
# Out:
# ['Shape Of You', 'Believer', 'Blinding Lights']

# %%
#task 2
products = ['Shoes', 't-shirt', 'Smartphone', 'watch', 'Speaker']

result = list(filter(lambda p: p.lower().startswith('s'), products))

print(result)
# Out:
# ['Shoes', 'Smartphone', 'Speaker']

# %%
#task 4
from functools import reduce

orders = [120, 340, 560, 80]

total = reduce(lambda x, y: x + y, orders)

print("Total bill:", total)
# Out:
# Total bill: 1100
